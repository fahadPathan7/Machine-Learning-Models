# %%
from numpy import loadtxt
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Input Variables:
#
#
# ---
#
#
# 1. Number of times pregnant
#
# 2. Plasma glucose concentration at 2 hours in an oral glucose tolerance test
#
# 3. Diastolic blood pressure (mm Hg)
#
# 4. Triceps skin fold thickness (mm)
#
# 5. 2-hour serum insulin (mu U/ml)
#
# 6. Body mass index (weight in kg/(height in m)^2)
#
# 7. Diabetes pedigree function
#
# 8. Age (years)
#
#
# Output Variable:
#
#
# ---
#
# Class variable (0 or 1)

# %%
data_path = '/content/drive/MyDrive/nn_data.txt'
dataset = pd.read_csv(data_path, header=None)
dataset.shape
print(dataset.head())
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
# split into input (X) and output (y) variables
# split into input (X) and output (y) variables
X = dataset.iloc[:,0:8]
y = dataset.iloc[:,8]

# %%
X.head()
# Out:
#    0    1   2   3    4     5      6   7
# 0  6  148  72  35    0  33.6  0.627  50
# 1  1   85  66  29    0  26.6  0.351  31
# 2  8  183  64   0    0  23.3  0.672  32
# 3  1   89  66  23   94  28.1  0.167  21
# 4  0  137  40  35  168  43.1  2.288  33

# %%
# define the keras model
model = Sequential()
model.add(Dense(8, input_shape=(8,), activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 2s 3ms/step - loss: 4.7174 - accuracy: 0.6185
# Epoch 2/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.9968 - accuracy: 0.5911
# Epoch 3/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7951 - accuracy: 0.6471
# Epoch 4/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7199 - accuracy: 0.6549
# Epoch 5/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6995 - accuracy: 0.6654
# Epoch 6/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6721 - accuracy: 0.6589
# Epoch 7/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6698 - accuracy: 0.6862
# Epoch 8/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6416 - accuracy: 0.6706
# Epoch 9/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6341 - accuracy: 0.6680
# Epoch 10/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6240 - accuracy: 0.6940
# Epoch 11/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6097 - accuracy: 0.6862
# Epoch 12/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6108 - accuracy: 0.6823
# Epoch 13/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6088 - accuracy: 0.6888
# Epoch 14/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6049 - accuracy: 0.6875
# Epoch 15/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5893 - accuracy: 0.7044
# Epoch 16/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5872 - accuracy: 0.7148
# Epoch 17/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5794 - accuracy: 0.7044
# Epoch 18/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5897 - accuracy: 0.6966
# Epoch 19/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5901 - accuracy: 0.7122
# Epoch 20/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5768 - accuracy: 0.6914
# Epoch 21/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5917 - accuracy: 0.7018
# Epoch 22/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5793 - accuracy: 0.7148
# Epoch 23/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5721 - accuracy: 0.7135
# Epoch 24/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5760 - accuracy: 0.7109
# Epoch 25/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5763 - accuracy: 0.7214
# Epoch 26/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5738 - accuracy: 0.7161
# Epoch 27/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5657 - accuracy: 0.7135
# Epoch 28/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5642 - accuracy: 0.7005
# Epoch 29/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5629 - accuracy: 0.7070
# Epoch 30/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5571 - accuracy: 0.7253
# Epoch 31/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5618 - accuracy: 0.7214
# Epoch 32/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5599 - accuracy: 0.7174
# Epoch 33/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5601 - accuracy: 0.7148
# Epoch 34/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5737 - accuracy: 0.7174
# Epoch 35/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5656 - accuracy: 0.7148
# Epoch 36/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5483 - accuracy: 0.7266
# Epoch 37/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5570 - accuracy: 0.7214
# Epoch 38/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5724 - accuracy: 0.7227
# Epoch 39/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5482 - accuracy: 0.7240
# Epoch 40/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5504 - accuracy: 0.7279
# Epoch 41/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5547 - accuracy: 0.7266
# Epoch 42/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5581 - accuracy: 0.7201
# Epoch 43/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5519 - accuracy: 0.7188
# Epoch 44/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5543 - accuracy: 0.7253
# Epoch 45/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5613 - accuracy: 0.7214
# Epoch 46/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5528 - accuracy: 0.7279
# Epoch 47/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5460 - accuracy: 0.7318
# Epoch 48/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5520 - accuracy: 0.7331
# Epoch 49/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5574 - accuracy: 0.7214
# Epoch 50/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5549 - accuracy: 0.7253
# Epoch 51/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5458 - accuracy: 0.7357
# Epoch 52/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7266
# Epoch 53/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5729 - accuracy: 0.7227
# Epoch 54/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5484 - accuracy: 0.7292
# Epoch 55/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5494 - accuracy: 0.7266
# Epoch 56/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5338 - accuracy: 0.7344
# Epoch 57/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5377 - accuracy: 0.7552
# Epoch 58/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5290 - accuracy: 0.7396
# Epoch 59/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5533 - accuracy: 0.7435
# Epoch 60/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5348 - accuracy: 0.7344
# Epoch 61/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5250 - accuracy: 0.7474
# Epoch 62/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5385 - accuracy: 0.7461
# Epoch 63/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5306 - accuracy: 0.7422
# Epoch 64/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5334 - accuracy: 0.7474
# Epoch 65/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5311 - accuracy: 0.7266
# Epoch 66/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5259 - accuracy: 0.7422
# Epoch 67/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5265 - accuracy: 0.7357
# Epoch 68/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5422 - accuracy: 0.7487
# Epoch 69/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5302 - accuracy: 0.7357
# Epoch 70/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5209 - accuracy: 0.7461
# Epoch 71/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5275 - accuracy: 0.7357
# Epoch 72/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5235 - accuracy: 0.7253
# Epoch 73/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5270 - accuracy: 0.7409
# Epoch 74/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5228 - accuracy: 0.7396
# Epoch 75/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5168 - accuracy: 0.7383
# Epoch 76/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5335 - accuracy: 0.7292
# Epoch 77/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5188 - accuracy: 0.7344
# Epoch 78/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5180 - accuracy: 0.7448
# Epoch 79/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5387 - accuracy: 0.7331
# Epoch 80/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5256 - accuracy: 0.7422
# Epoch 81/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5104 - accuracy: 0.7565
# Epoch 82/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5113 - accuracy: 0.7448
# Epoch 83/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5145 - accuracy: 0.7409
# Epoch 84/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5062 - accuracy: 0.7474
# Epoch 85/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5063 - accuracy: 0.7591
# Epoch 86/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5119 - accuracy: 0.7370
# Epoch 87/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5180 - accuracy: 0.7318
# Epoch 88/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5032 - accuracy: 0.7500
# Epoch 89/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5036 - accuracy: 0.7513
# Epoch 90/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5049 - accuracy: 0.7461
# Epoch 91/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5067 - accuracy: 0.7357
# Epoch 92/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5117 - accuracy: 0.7500
# Epoch 93/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5126 - accuracy: 0.7409
# Epoch 94/100
# 77/77 [==============================] - 0s 4ms/step - loss: 0.5029 - accuracy: 0.7539
# Epoch 95/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4989 - accuracy: 0.7539
# Epoch 96/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5101 - accuracy: 0.7500
# Epoch 97/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5148 - accuracy: 0.7409
# Epoch 98/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5057 - accuracy: 0.7448
# Epoch 99/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5005 - accuracy: 0.7526
# Epoch 100/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5040 - accuracy: 0.7552

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4959 - accuracy: 0.7435
# Accuracy: 74.35

# %%
# make class predictions with the model
predictions = (model.predict(X) > 0.5).astype(int)
# summarize the first 5 cases
for i in range(5):
	print(' %d (expected %d)' % ( predictions[i], y[i]))
# Out:
# 24/24 [==============================] - 0s 1ms/step
#  1 (expected 1)
#  0 (expected 0)
#  1 (expected 1)
#  0 (expected 0)
#  1 (expected 1)
